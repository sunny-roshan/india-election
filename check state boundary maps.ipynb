# %%
# Check India state boundary shapefiles

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
state1 = gpd.read_file("/Users/sunny/Library/CloudStorage/OneDrive-Personal/Documents/Python/Electoral maps project/maps-master/States/Admin2.shp")

# %%
state1
# Out:
#                                        ST_NM  \
# 0                          Arunachal Pradesh
# 1                                      Assam
# 2                                 Chandigarh
# 3                                  Karnataka
# 4                                    Manipur
# 5                                  Meghalaya
# 6                                    Mizoram
# 7                                   Nagaland
# 8                                     Punjab
# 9                                  Rajasthan
# 10                                    Sikkim
# 11                                   Tripura
# 12                               Uttarakhand
# 13                                 Telangana
# 14                                     Bihar
# 15                                    Kerala
# 16                            Madhya Pradesh
# 17                         Andaman & Nicobar
# 18                                   Gujarat
# 19                               Lakshadweep
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 10))
state1.boundary.plot(ax=ax, linewidth=0.15)
plt.show()

# %%
state2 = gpd.read_file("/Users/sunny/Library/CloudStorage/OneDrive-Personal/Documents/Python/Electoral maps project/maps-master/India-State-and-Country-Shapefile-Updated-Jan-2020-master/India_State_Boundary.shp")

# %%
state2
# Out:
#                                   State_Name  \
# 0                          Andaman & Nicobar
# 1                                 Chandigarh
# 2   Daman and Diu and Dadra and Nagar Haveli
# 3                                      Delhi
# 4                                    Haryana
# 5                                  Jharkhand
# 6                                  Karnataka
# 7                                     Kerala
# 8                                Lakshadweep
# 9                             Madhya Pradesh
# 10                               Maharashtra
# 11                                    Odisha
# 12                                Puducherry
# 13                                 Tamilnadu
# 14                             Chhattishgarh
# 15                                 Telengana
# 16                            Andhra Pradesh
# 17                                Puducherry
# 18                                       Goa
# 19                          Himachal Pradesh
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 10))
state1.boundary.plot(ax=ax, linewidth=0.15)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
state2.boundary.plot(ax=ax, linewidth=0.15)
plt.show()

# %%
print(state1.crs)
# Out:
# EPSG:4326

# %%
print(state2.crs)
# Out:
# EPSG:3857

# %%
state2 = state2.to_crs(epsg=4326)

# %%
print(state1.crs)
# Out:
# EPSG:4326

# %%
fig, ax = plt.subplots(figsize=(10, 10))
state1.boundary.plot(ax=ax, linewidth=0.15)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
state2.boundary.plot(ax=ax, linewidth=0.15)
plt.show()

# %%
state1 = state1.rename(columns={'ST_NM' : 'State_Name'})

# %%
check_same_boundaries = pd.merge(state1, state2, on=['State_Name'], how='outer')

# %%
check_same_boundaries
# Out:
#                                   State_Name  \
# 0                          Andaman & Nicobar
# 1                             Andhra Pradesh
# 2                          Arunachal Pradesh
# 3                                      Assam
# 4                                      Bihar
# 5                                 Chandigarh
# 6                               Chhattisgarh
# 7                              Chhattishgarh
# 8   Dadra and Nagar Haveli and Daman and Diu
# 9   Daman and Diu and Dadra and Nagar Haveli
# 10                                     Delhi
# 11                                       Goa
# 12                                   Gujarat
# 13                                   Haryana
# 14                          Himachal Pradesh
# 15                           Jammu & Kashmir
# 16                         Jammu and Kashmir
# 17                                 Jharkhand
# 18                                 Karnataka
# 19                                    Kerala
# ...
